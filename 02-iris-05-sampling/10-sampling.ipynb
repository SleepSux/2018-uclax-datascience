# %% [markdown]
# #### What percentage of the entire dataset is the first sample of three points? How well does this sample do in representing the entire dataset?

# %% [markdown]
# 2 percent. it pretty well. you can get a jist of what the data looks like.

# %% [markdown]
# #### What does this code do?
#
# Be as detailed as possible!
#
#     np.abs(iris_df.mean() - sample.mean())

# %% [markdown]
# It takes the absolute value of the diffrence between the whole data sets mean and the sample mean.

# %% [markdown]
# #### Why is it important to use the absolute value of the error?

# %% [markdown]
# So you can inlude all errors even if they are negative.

# %% [markdown]
# #### Why is it important to normalize the error by dividing by the standard deviation of the feature?

# %% [markdown]
# So that their scales can match in weight.

# %% [markdown]
# #### Why is it important to normalize the error by dividing by the standard deviation of the feature?

# %% [markdown]
# So that their scales can match in weight.

# %% [markdown]
# #### Prepare an Error Plot of all Four Features as a Function of `n`

# %%
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from IPython.display import display

# %matplotlib inline

IRIS = load_iris()
plt.rc('figure', figsize=(20, 6))
feat_names = IRIS.feature_names
iris_df = pd.DataFrame(IRIS.data, columns=feat_names)

iris_df['target'] = IRIS.target_names[IRIS.target]
def feature_error_by_n(data, feature, n):
    sample = data[feature].sample(n)
    error = np.abs((data[feature].mean() - sample.mean())/data[feature].mean())
    return error



sepal_length_error_by_n = [feature_error_by_n(iris_df, 'sepal length (cm)', n) for n in range(1,151)]
plt.plot(range(1,151), sepal_length_error_by_n, label='absolute error - sepal length mean by sample n')
plt.legend()

sepal_width_error_by_n = [feature_error_by_n(iris_df, 'sepal width (cm)', n) for n in range(1,151)]
plt.plot(range(1,151), sepal_width_error_by_n, label='absolute error - sepal width mean by sample n')
plt.legend()

petal_width_error_by_n = [feature_error_by_n(iris_df, 'petal width (cm)', n) for n in range(1,151)]
plt.plot(range(1,151), petal_width_error_by_n, label='absolute error - petal width mean by sample n')
plt.legend()

petal_length_error_by_n = [feature_error_by_n(iris_df, 'petal length (cm)', n) for n in range(1,151)]
plt.plot(range(1,151), petal_length_error_by_n, label='absolute error - petal length mean by sample n')
plt.legend()

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# 11                 4.8               3.4                1.6               0.2
# 12                 4.8               3.0                1.4               0.1
# 13                 4.3               3.0                1.1               0.1
# 14                 5.8               4.0                1.2               0.2
# 15                 5.7               4.4                1.5               0.4
# 16                 5.4               3.9                1.3               0.4
# 17                 5.1               3.5                1.4               0.3
# 18                 5.7               3.8                1.7               0.3
# 19                 5.1               3.8                1.5               0.3
# 20                 5.4               3.4                1.7               0.2
# 21                 5.1               3.7                1.5               0.4
# 22                 4.6               3.6                1.0               0.2
# 23                 5.1               3.3                1.7               0.5
# 24                 4.8               3.4                1.9               0.2
# 25                 5.0               3.0                1.6               0.2
# 26                 5.0               3.4                1.6               0.4
# 27                 5.2               3.5                1.5               0.2
# 28                 5.2               3.4                1.4               0.2
# 29                 4.7               3.2                1.6               0.2
# ..                 ...               ...                ...               ...
# 120                6.9               3.2                5.7               2.3
# 121                5.6               2.8                4.9               2.0
# 122                7.7               2.8                6.7               2.0
# 123                6.3               2.7                4.9               1.8
# 124                6.7               3.3                5.7               2.1
# 125                7.2               3.2                6.0               1.8
# 126                6.2               2.8                4.8               1.8
# 127                6.1               3.0                4.9               1.8
# 128                6.4               2.8                5.6               2.1
# 129                7.2               3.0                5.8               1.6
# 130                7.4               2.8                6.1               1.9
# 131                7.9               3.8                6.4               2.0
# 132                6.4               2.8                5.6               2.2
# 133                6.3               2.8                5.1               1.5
# 134                6.1               2.6                5.6               1.4
# 135                7.7               3.0                6.1               2.3
# 136                6.3               3.4                5.6               2.4
# 137                6.4               3.1                5.5               1.8
# 138                6.0               3.0                4.8               1.8
# 139                6.9               3.1                5.4               2.1
# 140                6.7               3.1                5.6               2.4
# 141                6.9               3.1                5.1               2.3
# 142                5.8               2.7                5.1               1.9
# 143                6.8               3.2                5.9               2.3
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#         target
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# 5       setosa
# 6       setosa
# 7       setosa
# 8       setosa
# 9       setosa
# 10      setosa
# 11      setosa
# 12      setosa
# 13      setosa
# 14      setosa
# 15      setosa
# 16      setosa
# 17      setosa
# 18      setosa
# 19      setosa
# 20      setosa
# 21      setosa
# 22      setosa
# 23      setosa
# 24      setosa
# 25      setosa
# 26      setosa
# 27      setosa
# 28      setosa
# 29      setosa
# ..         ...
# 120  virginica
# 121  virginica
# 122  virginica
# 123  virginica
# 124  virginica
# 125  virginica
# 126  virginica
# 127  virginica
# 128  virginica
# 129  virginica
# 130  virginica
# 131  virginica
# 132  virginica
# 133  virginica
# 134  virginica
# 135  virginica
# 136  virginica
# 137  virginica
# 138  virginica
# 139  virginica
# 140  virginica
# 141  virginica
# 142  virginica
# 143  virginica
# 144  virginica
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### What does the error we have been calculating represent?

# %%
print('the error represents the probability of the sample size being wrong to how many samples you took from the actual data.')
# Out:
# the error represents the probability of the sample size being wrong to how many samples you took from the actual data.

# %%
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from IPython.display import display

# %matplotlib inline
plt.rc('figure', figsize=(20, 6))

# %%
IRIS = load_iris()

# %%
feat_names = IRIS.feature_names
iris_df = pd.DataFrame(IRIS.data, columns=feat_names)

iris_df['target'] = IRIS.target_names[IRIS.target]

# %%
iris_df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %% [markdown]
# ### Visualizing the Distributions of the Features

# %% [markdown]
# ### `pd.melt()`
#
# We can use `pandas.melt` to help with this visualization. Melt converts wide form data to long form data. So that
#
#     +---+---+---+
#     | A | B | C |
#     +===+===+===+
#     | 1 | 2 | 3 |
#     | 3 | 4 | 5 |
#     +---+---+---+
#
# becomes
#
#     +-----+-----+
#     | var | val |
#     +=====+=====+
#     |  A  |  1  |
#     |  A  |  3  |
#     |  B  |  2  |
#     |  B  |  4  |
#     |  C  |  3  |
#     |  C  |  5  |
#     +-----+-----+

# %% [markdown]
# Here, is a sample of the data

# %%
samp = iris_df.sample(5)
samp
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 119                6.0               2.2                5.0               1.5
# 57                 4.9               2.4                3.3               1.0
# 73                 6.1               2.8                4.7               1.2
# 30                 4.8               3.1                1.6               0.2
# 134                6.1               2.6                5.6               1.4
#
#          target
# 119   virginica
# 57   versicolor
# 73   versicolor
# 30       setosa
# 134   virginica

# %% [markdown]
# And it becomes

# %%
samp_melt = pd.melt(samp.select_dtypes([float]))
samp_melt
# Out:
#              variable  value
# 0   sepal length (cm)    6.0
# 1   sepal length (cm)    4.9
# 2   sepal length (cm)    6.1
# 3   sepal length (cm)    4.8
# 4   sepal length (cm)    6.1
# 5    sepal width (cm)    2.2
# 6    sepal width (cm)    2.4
# 7    sepal width (cm)    2.8
# 8    sepal width (cm)    3.1
# 9    sepal width (cm)    2.6
# 10  petal length (cm)    5.0
# 11  petal length (cm)    3.3
# 12  petal length (cm)    4.7
# 13  petal length (cm)    1.6
# 14  petal length (cm)    5.6
# 15   petal width (cm)    1.5
# 16   petal width (cm)    1.0
# 17   petal width (cm)    1.2
# 18   petal width (cm)    0.2
# 19   petal width (cm)    1.4

# %% [markdown]
# This is the exact format expected of the box plot in Seaborn.

# %%
iris_melt = pd.melt(iris_df.select_dtypes([float]))

# %%
fig = plt.figure(figsize=(20,4))
sns.boxplot(x='variable', y='value', data=iris_melt)
plt.ylim(-1,9)

_, ax = plt.subplots(1,4, figsize=(20,4))
iris_numerical_df = iris_df.select_dtypes([float])

for i, feat in enumerate(iris_numerical_df.columns):
    sns.distplot(iris_numerical_df[feat], ax=ax[i])
    #ax[i].set_xlim(-1,9)
    ax[i].axvline(iris_numerical_df[feat].mean())
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # Sampling the Dataset
#
# In this notebook, we begin to explore the iris dataset by sampling. First, let's sample three random points and examine them.

# %%
np.random.seed(42)

# %%
sample_1 = iris_df.sample(3)

# %%
sample_1
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 73                 6.1               2.8                4.7               1.2
# 18                 5.7               3.8                1.7               0.3
# 118                7.7               2.6                6.9               2.3
#
#          target
# 73   versicolor
# 18       setosa
# 118   virginica

# %%
iris_df.describe().T
# Out:
#                    count      mean       std  min  25%   50%  75%  max
# sepal length (cm)  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal width (cm)   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# petal length (cm)  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# petal width (cm)   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %%
sample_1.describe().T
# Out:
#                    count      mean       std  min   25%  50%   75%  max
# sepal length (cm)    3.0  6.500000  1.058301  5.7  5.90  6.1  6.90  7.7
# sepal width (cm)     3.0  3.066667  0.642910  2.6  2.70  2.8  3.30  3.8
# petal length (cm)    3.0  4.433333  2.610236  1.7  3.20  4.7  5.80  6.9
# petal width (cm)     3.0  1.266667  1.001665  0.3  0.75  1.2  1.75  2.3

# %% [markdown]
# ## Visualize the Differences Using Seaborn

# %% [markdown]
# ### VIsualized with a Box Plot

# %%
sample_1_melt = pd.melt(sample_1.select_dtypes([float]))

# %%
_, ax = plt.subplots(1, 2, figsize=(20,5))

sns.boxplot(x='variable', y='value', data=sample_1_melt, ax=ax[0])
ax[0].set_title('Sample')

sns.boxplot(x='variable', y='value', data=iris_melt, ax=ax[1])
ax[1].set_title('Full Data Set');

# %% [markdown]
# ### Visualized with a Swarmplot

# %%
_, ax = plt.subplots(1, 2, figsize=(20,5))

sns.swarmplot(x='variable', y='value', data=sample_1_melt, ax=ax[0])
ax[0].set_title('Sample')

sns.swarmplot(x='variable', y='value', data=iris_melt, ax=ax[1])
ax[1].set_title('Full Data Set');

# %% [markdown]
# ### Visualized with a Stripplot

# %%
_, ax = plt.subplots(1, 2, figsize=(20,5))

sns.stripplot(x='variable', y='value', data=sample_1_melt, ax=ax[0])
ax[0].set_title('Sample')

sns.stripplot(x='variable', y='value', data=iris_melt, ax=ax[1])
ax[1].set_title('Full Data Set');

# %% [markdown]
# ### Visualized with a Violinplot

# %%
_, ax = plt.subplots(1, 2, figsize=(20,5))

sns.violinplot(x='variable', y='value', data=sample_1_melt, ax=ax[0])
ax[0].set_title('Sample')

sns.violinplot(x='variable', y='value', data=iris_melt, ax=ax[1])
ax[1].set_title('Full Data Set');

# %% [markdown]
# ### Measure the Performance

# %%
error_sample_1 = np.abs(iris_df.mean() - sample_1.mean())
error_sample_1
# Out:
# sepal length (cm)    0.656667
# sepal width (cm)     0.012667
# petal length (cm)    0.674667
# petal width (cm)     0.068000
# dtype: float64

# %% [markdown]
# #### Normalized

# %%
error_sample_1_normalized = np.abs((iris_df.mean() - sample_1.mean())/iris_df.mean())
error_sample_1_normalized
# Out:
# sepal length (cm)    0.112379
# sepal width (cm)     0.004148
# petal length (cm)    0.179496
# petal width (cm)     0.056730
# dtype: float64

# %% [markdown]
# ## A Second Sample

# %%
sample_2 = iris_df.sample(3)

sample_2_melt = pd.melt(sample_2.select_dtypes([float]))
iris_melt = pd.melt(iris_df.select_dtypes([float]))

_, ax = plt.subplots(1, 2, figsize=(20,5))

sns.boxplot(x='variable', y='value', data=sample_2_melt, ax=ax[0])
ax[0].set_title('Sample')

sns.boxplot(x='variable', y='value', data=iris_melt, ax=ax[1])
ax[1].set_title('Full Data Set');

# %%
error_sample_2_normalized = np.abs((iris_df.mean() - sample_2.mean())/iris_df.mean())

# %%
display(error_sample_1_normalized)
display(error_sample_2_normalized)
# Out:
# sepal length (cm)    0.112379
# sepal width (cm)     0.004148
# petal length (cm)    0.179496
# petal width (cm)     0.056730
# dtype: float64
# sepal length (cm)    0.110097
# sepal width (cm)     0.025977
# petal length (cm)    0.326002
# petal width (cm)     0.443826
# dtype: float64

# %% [markdown]
# ### What about a larger sample?

# %%
sample_3 = iris_df.sample(15)

sample_3_melt = pd.melt(sample_3.select_dtypes([float]))
iris_melt = pd.melt(iris_df.select_dtypes([float]))

_, ax = plt.subplots(1, 2, figsize=(20,5))

sns.boxplot(x='variable', y='value', data=sample_3_melt, ax=ax[0])
ax[0].set_title('Sample')

sns.boxplot(x='variable', y='value', data=iris_melt, ax=ax[1])
ax[1].set_title('Full Data Set');

# %%
error_sample_3_normalized = np.abs((iris_df.mean() - sample_3.mean())/iris_df.mean())

# %%
display(error_sample_1_normalized)
display(error_sample_2_normalized)
display(error_sample_3_normalized)
# Out:
# sepal length (cm)    0.112379
# sepal width (cm)     0.004148
# petal length (cm)    0.179496
# petal width (cm)     0.056730
# dtype: float64
# sepal length (cm)    0.110097
# sepal width (cm)     0.025977
# petal length (cm)    0.326002
# petal width (cm)     0.443826
# dtype: float64
# sepal length (cm)    0.057616
# sepal width (cm)     0.017245
# petal length (cm)    0.103228
# petal width (cm)     0.117909
# dtype: float64

# %% [markdown]
# # Plot the Error as a Function of Sample Size

# %% [markdown]
# It might be useful to begin to think about the error in the mean as a function of sample size.

# %%
def feature_error_by_n(data, feature, n):
    sample = data[feature].sample(n)
    error = np.abs((data[feature].mean() - sample.mean())/data[feature].mean())
    return error

# %%
iris_df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
feature_error_by_n(iris_df, 'sepal length (cm)', 3)
# Out:
# 0.14660581859669133

# %% [markdown]
# Use a list comprehension to generate errors for every possible value of `n`.

# %%
sepal_length_error_by_n = [feature_error_by_n(iris_df, 'sepal length (cm)', n) for n in range(1,151)]

# %%
plt.plot(range(1,151), sepal_length_error_by_n, label='absolute error - sepal length mean by sample n')
plt.legend()
